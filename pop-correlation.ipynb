# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pylab
import seaborn as sns
matplotlib.rcParams['figure.figsize'] = [16.0, 10.0]

# %%
from itertools import cycle, islice

styles = list(islice(cycle(['X-', '<-', '.-', 'v-', '*-', 'o-', '>-', '^-', 'd-', 's-', '+-']), 100))
markers = list(islice(cycle(['X', '<', '.', 'v', '*', 'o', '>', '^', 'd', 's', '+']), 100))

def get_markers(n):
    return markers[:n]

# %%
df1M = pd.read_csv("data/results-all-ml-1M-pop.csv", index_col=('Percentage', 'Recommender'))
dfLT = pd.read_csv("data/results-all-libraryThing-pop.csv", index_col=('Percentage', 'Recommender'))
dfBA = pd.read_csv("data/results-all-beerAdvocate-pop.csv", index_col=('Percentage', 'Recommender'))

# %%
import re


def without_cutoff(metric):
    return re.fullmatch('.*_[0-9]+', metric) is None

def computeTau(df, metrics=None):
    percentages = df.index.levels[0]
    if metrics is None:
        metrics = list(filter(without_cutoff, df.columns))
    tau = pd.DataFrame(0.0, columns=metrics, index=percentages)

    for percentage in percentages:
        # Reference data
        refdf = df.loc[1.00]

        # Comparison data
        mydf = df.loc[percentage]

        for metric in metrics:
            # Compute Kendall for each metric
            tau[metric][percentage] = mydf[metric].corr(refdf[metric], method="kendall")

    return tau

# %%
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages


def plot_in_pdf(filename, titles, dfs, ylabel, metrics=None, xlim=[1.0, 0.8], ylim=[0.0, 1.0]):
    with PdfPages(filename) as pdf:
        for title, df in zip(titles, dfs):
            ax = df.plot(colormap='Set1', style=styles)
            ax.invert_xaxis()
            ax.legend(bbox_to_anchor=(1.02, 1), loc=2)
            ax.set_title(title)
            ax.set_ylabel(ylabel)
            ax.set_xlim(xlim)
            ax.set_ylim(ylim)
            pdf.savefig(bbox_inches='tight')
            plt.close()

# %%
from xlsxwriter.utility import xl_col_to_name


def write_excel(filename, dfs, names):
    with pd.ExcelWriter(filename, engine='xlsxwriter') as writer:
        for df, name in zip(dfs, names):
            df.to_excel(writer, sheet_name=name)
            n_percentages = len(df.index)
            count = 1
            worksheet = writer.sheets[name]
            median = df.median().mean()
            minimum = df.min().min()
            for column in df.columns:
                fmt = "{c}2:{c}{n}".format(c=xl_col_to_name(count), n=n_percentages + 1)
                count += 1
                worksheet.conditional_format(fmt, {'type': '3_color_scale',
                                                   'min_type': 'num',
                                                   'mid_type': 'num',
                                                   'max_type': 'num',
                                                   'min_value': minimum,
                                                   'mid_value': median,
                                                   'max_value': 1.0})

# %%
from multiprocessing import Pool


dfs = [df1M, dfLT, dfBA]
    
titles = ['MovieLens 1M (pop qrels)', 'LibraryThing (pop qrels)', 'BeerAdvocate (pop qrels)']
names = ['MovieLens 1M', 'LibraryThing', 'BeerAdvocate']
metrics = ['bpref', 'err', 'infAP2', 'map', 'ndcg', 'qm', 'recip_rank', 'set_F', 'set_P', 'set_recall']


with Pool() as pool:
    taus = pool.starmap(computeTau, [(df, metrics) for df in dfs])

plot_in_pdf('results/pop/pop_kendall.pdf', titles, taus, "Kendall's tau")
write_excel('results/pop/pop_kendall.xlsx', taus, names)

# %%
from multiprocessing import Pool


dfs = [df1M, dfLT, dfBA]
titles = ['MovieLens 1M (pop qrels)', 'LibraryThing (pop qrels)', 'BeerAdvocate (pop qrels)']
names =   ['MovieLens 1M', 'LibraryThing', 'BeerAdvocate']

precs =   ['P_5', 'P_10', 'P_20', 'P_30', 'P_40', 'P_50', 'P_60', 'P_70',
           'P_80', 'P_90', 'P_100']
recalls = ['recall_5', 'recall_10', 'recall_20', 'recall_30', 'recall_40',
           'recall_50', 'recall_60', 'recall_70', 'recall_80', 'recall_90',
           'recall_100']
maps =    ['map_cut_5', 'map_cut_10', 'map_cut_20', 'map_cut_30',
           'map_cut_40', 'map_cut_50', 'map_cut_60', 'map_cut_70',
           'map_cut_80', 'map_cut_90', 'map_cut_100']
ndcgs =   ['ndcg_cut_5', 'ndcg_cut_10', 'ndcg_cut_20', 'ndcg_cut_30',
           'ndcg_cut_40', 'ndcg_cut_50', 'ndcg_cut_60', 'ndcg_cut_70',
           'ndcg_cut_80', 'ndcg_cut_90', 'ndcg_cut_100']
ndcg2s =  ['ndcg2_cut_5', 'ndcg2_cut_10', 'ndcg2_cut_20', 'ndcg2_cut_30',
           'ndcg2_cut_40', 'ndcg2_cut_50', 'ndcg2_cut_60', 'ndcg2_cut_70',
           'ndcg2_cut_80', 'ndcg2_cut_90', 'ndcg2_cut_100']
ndcg45s = ['ndcg45_cut_5', 'ndcg45_cut_10', 'ndcg45_cut_20', 'ndcg45_cut_30',
           'ndcg45_cut_40', 'ndcg45_cut_50', 'ndcg45_cut_60', 'ndcg45_cut_70',
           'ndcg45_cut_80', 'ndcg45_cut_90', 'ndcg45_cut_100']
qms =     ['qm_cut_5', 'qm_cut_10', 'qm_cut_20', 'qm_cut_30',
           'qm_cut_40', 'qm_cut_50', 'qm_cut_60', 'qm_cut_70',
           'qm_cut_80', 'qm_cut_90', 'qm_cut_100']
qm45s =   ['qm45_cut_5', 'qm45_cut_10', 'qm45_cut_20', 'qm45_cut_30',
           'qm45_cut_40', 'qm45_cut_50', 'qm45_cut_60', 'qm45_cut_70',
           'qm45_cut_80', 'qm45_cut_90', 'qm45_cut_100']

for metric_name, metrics in zip(
    ['precision', 'recall', 'map', 'ndcg', 'ndcg2', 'ndcg45', 'qm', 'qm45'],
    [precs, recalls, maps, ndcgs, ndcg2s, ndcg45s, qms, qm45s]):
    with Pool() as pool:
        taus_cutoffs = pool.starmap(computeTau, [(df, metrics) for df in dfs])

    plot_in_pdf('results/pop/pop_kendall_' + metric_name + '_cutoffs.pdf', titles, taus_cutoffs, "Kendall's tau")
    write_excel('results/pop/pop_kendall_' + metric_name + '_cutoffs.xlsx', taus_cutoffs, names)

# %%
ndcgs = ['ndcg_cut_5', 'ndcg_cut_10', 'ndcg_cut_20', 'ndcg_cut_30',
         'ndcg_cut_40', 'ndcg_cut_50', 'ndcg_cut_60', 'ndcg_cut_70',
         'ndcg_cut_80', 'ndcg_cut_90', 'ndcg_cut_100']

df = computeTau(df1M, ndcgs)
df.columns = ['nDCG@5', 'nDCG@10', 'nDCG@20', 'nDCG@30', 'nDCG@40','nDCG@50',
              'nDCG@60', 'nDCG@70', 'nDCG@80', 'nDCG@90', 'nDCG@100']
df.index = df.index * 100

# %%
matplotlib.rcParams['figure.figsize'] = [6, 2.8]
sns.set_style("ticks")
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

p = sns.color_palette("Set1", 9)
p.append((0.090196078431372548, 0.74509803921568629, 0.81176470588235294))
p.append((0.73725490196078436, 0.74117647058823533, 0.13333333333333333))

dfs = [df1M, dfLT, dfBA]
ndcgs = ['ndcg_cut_5', 'ndcg_cut_10', 'ndcg_cut_20', 'ndcg_cut_30',
         'ndcg_cut_40', 'ndcg_cut_50', 'ndcg_cut_60', 'ndcg_cut_70',
         'ndcg_cut_80', 'ndcg_cut_90', 'ndcg_cut_100']
labels = ['nDCG@5', 'nDCG@10', 'nDCG@20', 'nDCG@30', 'nDCG@40','nDCG@50',
          'nDCG@60', 'nDCG@70', 'nDCG@80', 'nDCG@90', 'nDCG@100']

with PdfPages('results/pop/pop_kendall_ndcg_cutoffs_final.pdf') as pdf:
    for df in dfs:
        x = computeTau(df, ndcgs)
        x.columns = labels
        x.index = x.index * 100
        with sns.color_palette(p):
            ax = x.plot(style=styles, linewidth=1.3, markersize=7)
            ax.invert_xaxis()
            ax.legend(ncol=3)
            ax.set_ylabel("Kendall's $\\tau$")
            ax.set_xlabel("\% least popular items in the test set")
            ax.set_xlim([100.0, 80.0])
            ax.set_ylim([0.0, 1.0])
            plt.xticks(np.arange(100, 79, -5))
            sns.despine()
            pdf.savefig(bbox_inches='tight')
            plt.close()

# %%
matplotlib.rcParams['figure.figsize'] = [6, 2.8]
sns.set_style("ticks")
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

p = sns.color_palette("Set1", 9)
p.append((0.090196078431372548, 0.74509803921568629, 0.81176470588235294))
p.append((0.73725490196078436, 0.74117647058823533, 0.13333333333333333))

metrics = ['set_P', 'set_recall', 'map',  'ndcg', 'recip_rank', 'bpref', 'infAP2']
new_names = ['P', 'Recall', 'MAP', 'nDCG', 'MRR', 'bpref', 'infAP']

with PdfPages('results/pop/pop_kendall_final.pdf') as pdf:
    for df in taus:
        x = df[metrics]
        x.columns = new_names
        x.index *= 100
        with sns.color_palette(p):
            ax = x.plot(style=styles, linewidth=1.3, markersize=7)
            ax.invert_xaxis()
            ax.legend(ncol=3)
            ax.set_ylabel("Kendall's $\\tau$")
            ax.set_xlabel("\% least popular items in the test set")
            ax.set_xlim([100.0, 80.0])
            ax.set_ylim([0.0, 1.0])
            plt.xticks(np.arange(100, 79, -5))
            sns.despine()
            pdf.savefig(bbox_inches='tight')
            plt.close()

# %%
df1M.loc[0.95]
# Out:
#                           P_10   P_100    P_20    P_30    P_40     P_5  \
# Recommender
# run-CHI2-ml-1M          0.1072  0.0479  0.0890  0.0783  0.0707  0.1258
# run-BPRMF-ml-1M         0.0684  0.0480  0.0644  0.0620  0.0596  0.0714
# run-HT-ml-1M            0.0064  0.0154  0.0092  0.0113  0.0127  0.0040
# run-KLD-ml-1M           0.0375  0.0382  0.0423  0.0433  0.0432  0.0302
# run-LDA-ml-1M           0.0625  0.0466  0.0624  0.0602  0.0581  0.0624
# run-LM-WSR-UB-ml-1M     0.0431  0.0431  0.0500  0.0513  0.0509  0.0341
# run-LM-WSR-IB-ml-1M     0.0444  0.0435  0.0484  0.0503  0.0499  0.0396
# run-NNCosNgbr-UB-ml-1M  0.0073  0.0074  0.0083  0.0085  0.0084  0.0067
# run-NNCosNgbr-IB-ml-1M  0.0145  0.0120  0.0140  0.0135  0.0133  0.0152
# run-PLSA-ml-1M          0.0594  0.0466  0.0598  0.0587  0.0573  0.0579
# run-Pop-ml-1M           0.0000  0.0034  0.0000  0.0000  0.0000  0.0000
# run-PureSVD-ml-1M       0.0567  0.0499  0.0625  0.0633  0.0621  0.0446
# run-RM1-ml-1M           0.0116  0.0214  0.0168  0.0196  0.0208  0.0069
# run-RM2-ml-1M           0.0319  0.0401  0.0399  0.0424  0.0434  0.0238
# run-RSV-ml-1M           0.0110  0.0315  0.0187  0.0236  0.0266  0.0072
# run-RW-ml-1M            0.0110  0.0315  0.0188  0.0236  0.0266  0.0073
# run-Random-ml-1M        0.0041  0.0041  0.0039  0.0040  0.0040  0.0039
# run-SLIM-ml-1M          0.0587  0.0494  0.0612  0.0617  0.0600  0.0547
# run-SVD-ml-1M           0.0115  0.0118  0.0127  0.0128  0.0128  0.0094
# run-UIR-ml-1M           0.0000  0.0034  0.0000  0.0000  0.0000  0.0000
# run-WRMF-ml-1M          0.0788  0.0539  0.0791  0.0759  0.0719  0.0732
#
#                           P_50    P_60    P_70    P_80   ...    recall_60  \
# Recommender                                              ...
# run-CHI2-ml-1M          0.0649  0.0602  0.0565  0.0533   ...       0.3477
# run-BPRMF-ml-1M         0.0574  0.0553  0.0532  0.0514   ...       0.3311
# run-HT-ml-1M            0.0137  0.0144  0.0148  0.0152   ...       0.1306
# run-KLD-ml-1M           0.0426  0.0418  0.0411  0.0401   ...       0.2579
# run-LDA-ml-1M           0.0558  0.0537  0.0516  0.0499   ...       0.3090
# run-LM-WSR-UB-ml-1M     0.0500  0.0486  0.0471  0.0458   ...       0.2993
# run-LM-WSR-IB-ml-1M     0.0495  0.0484  0.0473  0.0459   ...       0.2946
# run-NNCosNgbr-UB-ml-1M  0.0084  0.0081  0.0079  0.0077   ...       0.0471
# run-NNCosNgbr-IB-ml-1M  0.0131  0.0128  0.0126  0.0123   ...       0.0638
# run-PLSA-ml-1M          0.0555  0.0534  0.0516  0.0498   ...       0.3078
# run-Pop-ml-1M           0.0002  0.0006  0.0011  0.0018   ...       0.0005
# run-PureSVD-ml-1M       0.0602  0.0579  0.0557  0.0537   ...       0.3197
# run-RM1-ml-1M           0.0214  0.0218  0.0219  0.0218   ...       0.1364
# run-RM2-ml-1M           0.0436  0.0433  0.0427  0.0418   ...       0.2764
# run-RSV-ml-1M           0.0289  0.0302  0.0309  0.0312   ...       0.2004
# run-RW-ml-1M            0.0290  0.0302  0.0309  0.0311   ...       0.2005
# run-Random-ml-1M        0.0041  0.0041  0.0041  0.0040   ...       0.0182
# run-SLIM-ml-1M          0.0584  0.0565  0.0546  0.0529   ...       0.3371
# run-SVD-ml-1M           0.0126  0.0126  0.0124  0.0123   ...       0.0583
# run-UIR-ml-1M           0.0002  0.0006  0.0011  0.0018   ...       0.0005
# run-WRMF-ml-1M          0.0680  0.0645  0.0616  0.0588   ...       0.3594
#
#                         recall_70  recall_80  recall_90  recip_rank  \
# Recommender
# run-CHI2-ml-1M             0.3763     0.4011     0.4221      0.2757
# run-BPRMF-ml-1M            0.3631     0.3939     0.4223      0.1794
# run-HT-ml-1M               0.1549     0.1779     0.1990      0.0301
# run-KLD-ml-1M              0.2893     0.3165     0.3413      0.0957
# run-LDA-ml-1M              0.3424     0.3715     0.4004      0.1577
# run-LM-WSR-UB-ml-1M        0.3304     0.3601     0.3861      0.1027
# run-LM-WSR-IB-ml-1M        0.3263     0.3543     0.3810      0.1115
# run-NNCosNgbr-UB-ml-1M     0.0527     0.0590     0.0652      0.0252
# run-NNCosNgbr-IB-ml-1M     0.0726     0.0813     0.0898      0.0490
# run-PLSA-ml-1M             0.3422     0.3718     0.3985      0.1457
# run-Pop-ml-1M              0.0011     0.0023     0.0042      0.0010
# run-PureSVD-ml-1M          0.3532     0.3843     0.4111      0.1164
# run-RM1-ml-1M              0.1558     0.1736     0.1908      0.0394
# run-RM2-ml-1M              0.3089     0.3365     0.3643      0.0832
# run-RSV-ml-1M              0.2306     0.2571     0.2834      0.0445
# run-RW-ml-1M               0.2308     0.2566     0.2838      0.0446
# run-Random-ml-1M           0.0211     0.0240     0.0272      0.0178
# run-SLIM-ml-1M             0.3696     0.4004     0.4264      0.1472
# run-SVD-ml-1M              0.0685     0.0780     0.0862      0.0350
# run-UIR-ml-1M              0.0011     0.0023     0.0042      0.0010
# run-WRMF-ml-1M             0.3939     0.4225     0.4514      0.1645
#
#                              rmse   set_F   set_P  set_recall    yaap
# Recommender
# run-CHI2-ml-1M             3.5744  0.0768  0.0479      0.4422 -1.4522
# run-BPRMF-ml-1M            1.4879  0.0771  0.0480      0.4475 -1.5643
# run-HT-ml-1M               2.9110  0.0265  0.0154      0.2166 -1.9857
# run-KLD-ml-1M              3.5092  0.0613  0.0382      0.3644 -1.7420
# run-LDA-ml-1M              3.5275  0.0747  0.0466      0.4248 -1.6067
# run-LM-WSR-UB-ml-1M       27.8216  0.0693  0.0431      0.4097 -1.6863
# run-LM-WSR-IB-ml-1M       25.2802  0.0698  0.0435      0.4051 -1.6688
# run-NNCosNgbr-UB-ml-1M     0.8552  0.0120  0.0074      0.0703 -2.0097
# run-NNCosNgbr-IB-ml-1M     2.7531  0.0189  0.0120      0.0974 -1.9700
# run-PLSA-ml-1M             3.5468  0.0745  0.0466      0.4237 -1.6208
# run-Pop-ml-1M              0.3035  0.0042  0.0034      0.0069 -2.0494
# run-PureSVD-ml-1M          2.5317  0.0794  0.0499      0.4368 -1.6125
# run-RM1-ml-1M           1032.1184  0.0340  0.0214      0.2061 -1.9243
# run-RM2-ml-1M           2112.0841  0.0646  0.0401      0.3883 -1.7369
# run-RSV-ml-1M              3.4166  0.0506  0.0315      0.3098 -1.8621
# run-RW-ml-1M               2.0843  0.0505  0.0315      0.3095 -1.8621
# run-Random-ml-1M           0.9802  0.0062  0.0041      0.0301 -2.0401
# run-SLIM-ml-1M             2.6567  0.0792  0.0494      0.4521 -1.5802
# run-SVD-ml-1M              0.3018  0.0186  0.0118      0.0943 -1.9817
# run-UIR-ml-1M            305.9255  0.0042  0.0034      0.0070 -2.0492
# run-WRMF-ml-1M             2.3845  0.0860  0.0539      0.4772 -1.5194
#
# [21 rows x 105 columns]

# %%
def get_rankings(df, metric):
    x = pd.DataFrame()
    for percentage in df.index.levels[0]:
        x[percentage] = df.loc[percentage].sort_values([metric], ascending=False).index
    return x

# %%
get_rankings(df1M, "ndcg")
# Out:
#                       0.05                    0.10                    0.15  \
# 0             run-HT-ml-1M            run-HT-ml-1M            run-HT-ml-1M
# 1         run-Random-ml-1M        run-Random-ml-1M        run-Random-ml-1M
# 2   run-NNCosNgbr-IB-ml-1M           run-SVD-ml-1M           run-SVD-ml-1M
# 3            run-RM1-ml-1M  run-NNCosNgbr-UB-ml-1M  run-NNCosNgbr-UB-ml-1M
# 4           run-CHI2-ml-1M  run-NNCosNgbr-IB-ml-1M           run-RM2-ml-1M
# 5             run-RW-ml-1M           run-RM2-ml-1M  run-NNCosNgbr-IB-ml-1M
# 6            run-SVD-ml-1M           run-RM1-ml-1M           run-RM1-ml-1M
# 7           run-SLIM-ml-1M          run-PLSA-ml-1M         run-BPRMF-ml-1M
# 8           run-WRMF-ml-1M           run-UIR-ml-1M     run-LM-WSR-IB-ml-1M
# 9          run-BPRMF-ml-1M            run-RW-ml-1M          run-CHI2-ml-1M
# 10           run-UIR-ml-1M          run-SLIM-ml-1M          run-SLIM-ml-1M
# 11           run-RSV-ml-1M       run-PureSVD-ml-1M           run-RSV-ml-1M
# 12           run-KLD-ml-1M         run-BPRMF-ml-1M           run-UIR-ml-1M
# 13           run-RM2-ml-1M           run-RSV-ml-1M            run-RW-ml-1M
# 14       run-PureSVD-ml-1M          run-CHI2-ml-1M           run-Pop-ml-1M
# 15           run-Pop-ml-1M           run-Pop-ml-1M       run-PureSVD-ml-1M
# 16          run-PLSA-ml-1M     run-LM-WSR-UB-ml-1M          run-PLSA-ml-1M
# 17  run-NNCosNgbr-UB-ml-1M     run-LM-WSR-IB-ml-1M     run-LM-WSR-UB-ml-1M
# 18     run-LM-WSR-UB-ml-1M           run-LDA-ml-1M           run-LDA-ml-1M
# 19           run-LDA-ml-1M           run-KLD-ml-1M           run-KLD-ml-1M
# 20     run-LM-WSR-IB-ml-1M          run-WRMF-ml-1M          run-WRMF-ml-1M
#
#                       0.20                    0.25                    0.30  \
# 0             run-HT-ml-1M            run-HT-ml-1M            run-HT-ml-1M
# 1         run-Random-ml-1M        run-Random-ml-1M        run-Random-ml-1M
# 2   run-NNCosNgbr-UB-ml-1M  run-NNCosNgbr-UB-ml-1M  run-NNCosNgbr-UB-ml-1M
# 3            run-RM2-ml-1M           run-RM2-ml-1M           run-RM2-ml-1M
# 4            run-SVD-ml-1M           run-SVD-ml-1M           run-SVD-ml-1M
# 5          run-BPRMF-ml-1M          run-CHI2-ml-1M          run-CHI2-ml-1M
# 6      run-LM-WSR-IB-ml-1M         run-BPRMF-ml-1M         run-BPRMF-ml-1M
# 7   run-NNCosNgbr-IB-ml-1M     run-LM-WSR-IB-ml-1M           run-RM1-ml-1M
# 8           run-CHI2-ml-1M           run-RM1-ml-1M     run-LM-WSR-IB-ml-1M
# 9            run-RM1-ml-1M  run-NNCosNgbr-IB-ml-1M  run-NNCosNgbr-IB-ml-1M
# 10          run-SLIM-ml-1M          run-SLIM-ml-1M          run-SLIM-ml-1M
# 11          run-PLSA-ml-1M          run-PLSA-ml-1M          run-PLSA-ml-1M
# 12           run-LDA-ml-1M           run-UIR-ml-1M     run-LM-WSR-UB-ml-1M
# 13           run-UIR-ml-1M            run-RW-ml-1M            run-RW-ml-1M
# 14     run-LM-WSR-UB-ml-1M       run-PureSVD-ml-1M          run-WRMF-ml-1M
# 15           run-KLD-ml-1M           run-RSV-ml-1M           run-Pop-ml-1M
# 16            run-RW-ml-1M           run-Pop-ml-1M           run-RSV-ml-1M
# 17           run-RSV-ml-1M     run-LM-WSR-UB-ml-1M       run-PureSVD-ml-1M
# 18       run-PureSVD-ml-1M           run-LDA-ml-1M           run-LDA-ml-1M
# 19           run-Pop-ml-1M           run-KLD-ml-1M           run-KLD-ml-1M
# 20          run-WRMF-ml-1M          run-WRMF-ml-1M           run-UIR-ml-1M
#
#                       0.35                    0.40                    0.45  \
# 0             run-HT-ml-1M            run-HT-ml-1M            run-HT-ml-1M
# 1         run-Random-ml-1M           run-RM2-ml-1M           run-RM2-ml-1M
# 2            run-RM2-ml-1M        run-Random-ml-1M          run-CHI2-ml-1M
# 3   run-NNCosNgbr-UB-ml-1M           run-SVD-ml-1M        run-Random-ml-1M
# 4            run-SVD-ml-1M  run-NNCosNgbr-UB-ml-1M         run-BPRMF-ml-1M
# 5           run-CHI2-ml-1M          run-CHI2-ml-1M  run-NNCosNgbr-UB-ml-1M
# 6          run-BPRMF-ml-1M         run-BPRMF-ml-1M           run-SVD-ml-1M
# 7      run-LM-WSR-IB-ml-1M     run-LM-WSR-IB-ml-1M     run-LM-WSR-IB-ml-1M
# 8            run-RM1-ml-1M           run-RM1-ml-1M           run-RM1-ml-1M
# 9           run-SLIM-ml-1M          run-SLIM-ml-1M          run-SLIM-ml-1M
# 10  run-NNCosNgbr-IB-ml-1M  run-NNCosNgbr-IB-ml-1M  run-NNCosNgbr-IB-ml-1M
# 11          run-PLSA-ml-1M          run-PLSA-ml-1M          run-PLSA-ml-1M
# 12           run-LDA-ml-1M           run-LDA-ml-1M           run-LDA-ml-1M
# 13     run-LM-WSR-UB-ml-1M     run-LM-WSR-UB-ml-1M     run-LM-WSR-UB-ml-1M
# 14       run-PureSVD-ml-1M          run-WRMF-ml-1M          run-WRMF-ml-1M
# 15           run-Pop-ml-1M       run-PureSVD-ml-1M       run-PureSVD-ml-1M
# 16            run-RW-ml-1M            run-RW-ml-1M           run-KLD-ml-1M
# 17           run-RSV-ml-1M           run-RSV-ml-1M           run-RSV-ml-1M
# 18           run-KLD-ml-1M           run-Pop-ml-1M            run-RW-ml-1M
# 19           run-UIR-ml-1M           run-UIR-ml-1M           run-Pop-ml-1M
# 20          run-WRMF-ml-1M           run-KLD-ml-1M           run-UIR-ml-1M
#
#                       0.50           ...                              0.91  \
# 0             run-HT-ml-1M           ...                    run-CHI2-ml-1M
# 1           run-CHI2-ml-1M           ...                   run-BPRMF-ml-1M
# 2            run-RM2-ml-1M           ...                    run-WRMF-ml-1M
# 3          run-BPRMF-ml-1M           ...                    run-SLIM-ml-1M
# 4         run-Random-ml-1M           ...                     run-LDA-ml-1M
# 5      run-LM-WSR-IB-ml-1M           ...                    run-PLSA-ml-1M
# 6            run-SVD-ml-1M           ...               run-LM-WSR-IB-ml-1M
# 7           run-SLIM-ml-1M           ...                 run-PureSVD-ml-1M
# 8            run-RM1-ml-1M           ...               run-LM-WSR-UB-ml-1M
# 9   run-NNCosNgbr-UB-ml-1M           ...                     run-RM2-ml-1M
# 10          run-PLSA-ml-1M           ...                     run-KLD-ml-1M
# 11           run-LDA-ml-1M           ...                      run-HT-ml-1M
# 12  run-NNCosNgbr-IB-ml-1M           ...                     run-RSV-ml-1M
# 13     run-LM-WSR-UB-ml-1M           ...                      run-RW-ml-1M
# 14          run-WRMF-ml-1M           ...                     run-RM1-ml-1M
# 15           run-KLD-ml-1M           ...            run-NNCosNgbr-IB-ml-1M
# 16       run-PureSVD-ml-1M           ...                     run-SVD-ml-1M
# 17            run-RW-ml-1M           ...            run-NNCosNgbr-UB-ml-1M
# 18           run-RSV-ml-1M           ...                  run-Random-ml-1M
# 19           run-Pop-ml-1M           ...                     run-UIR-ml-1M
# 20           run-UIR-ml-1M           ...                     run-Pop-ml-1M
#
#                       0.92                    0.93                    0.94  \
# 0           run-CHI2-ml-1M          run-CHI2-ml-1M          run-CHI2-ml-1M
# 1          run-BPRMF-ml-1M         run-BPRMF-ml-1M         run-BPRMF-ml-1M
# 2           run-WRMF-ml-1M          run-WRMF-ml-1M          run-WRMF-ml-1M
# 3           run-SLIM-ml-1M          run-SLIM-ml-1M          run-SLIM-ml-1M
# 4            run-LDA-ml-1M           run-LDA-ml-1M           run-LDA-ml-1M
# 5           run-PLSA-ml-1M          run-PLSA-ml-1M          run-PLSA-ml-1M
# 6        run-PureSVD-ml-1M       run-PureSVD-ml-1M       run-PureSVD-ml-1M
# 7      run-LM-WSR-IB-ml-1M     run-LM-WSR-IB-ml-1M     run-LM-WSR-IB-ml-1M
# 8      run-LM-WSR-UB-ml-1M     run-LM-WSR-UB-ml-1M     run-LM-WSR-UB-ml-1M
# 9            run-RM2-ml-1M           run-RM2-ml-1M           run-RM2-ml-1M
# 10           run-KLD-ml-1M           run-KLD-ml-1M           run-KLD-ml-1M
# 11            run-HT-ml-1M            run-HT-ml-1M           run-RSV-ml-1M
# 12           run-RSV-ml-1M           run-RSV-ml-1M            run-RW-ml-1M
# 13            run-RW-ml-1M            run-RW-ml-1M            run-HT-ml-1M
# 14           run-RM1-ml-1M           run-RM1-ml-1M           run-RM1-ml-1M
# 15  run-NNCosNgbr-IB-ml-1M  run-NNCosNgbr-IB-ml-1M  run-NNCosNgbr-IB-ml-1M
# 16           run-SVD-ml-1M           run-SVD-ml-1M           run-SVD-ml-1M
# 17  run-NNCosNgbr-UB-ml-1M  run-NNCosNgbr-UB-ml-1M  run-NNCosNgbr-UB-ml-1M
# 18        run-Random-ml-1M        run-Random-ml-1M        run-Random-ml-1M
# 19           run-UIR-ml-1M           run-Pop-ml-1M           run-Pop-ml-1M
# 20           run-Pop-ml-1M           run-UIR-ml-1M           run-UIR-ml-1M
#
#                       0.95                    0.96                    0.97  \
# 0           run-CHI2-ml-1M          run-CHI2-ml-1M          run-CHI2-ml-1M
# 1          run-BPRMF-ml-1M         run-BPRMF-ml-1M         run-BPRMF-ml-1M
# 2           run-WRMF-ml-1M          run-WRMF-ml-1M          run-WRMF-ml-1M
# 3           run-SLIM-ml-1M          run-SLIM-ml-1M          run-SLIM-ml-1M
# 4            run-LDA-ml-1M           run-LDA-ml-1M           run-LDA-ml-1M
# 5           run-PLSA-ml-1M          run-PLSA-ml-1M       run-PureSVD-ml-1M
# 6        run-PureSVD-ml-1M       run-PureSVD-ml-1M          run-PLSA-ml-1M
# 7      run-LM-WSR-IB-ml-1M     run-LM-WSR-IB-ml-1M     run-LM-WSR-IB-ml-1M
# 8      run-LM-WSR-UB-ml-1M     run-LM-WSR-UB-ml-1M     run-LM-WSR-UB-ml-1M
# 9            run-RM2-ml-1M           run-RM2-ml-1M           run-RM2-ml-1M
# 10           run-KLD-ml-1M           run-KLD-ml-1M           run-KLD-ml-1M
# 11           run-RSV-ml-1M           run-RSV-ml-1M            run-RW-ml-1M
# 12            run-RW-ml-1M            run-RW-ml-1M           run-RSV-ml-1M
# 13            run-HT-ml-1M           run-RM1-ml-1M           run-RM1-ml-1M
# 14           run-RM1-ml-1M            run-HT-ml-1M            run-HT-ml-1M
# 15  run-NNCosNgbr-IB-ml-1M  run-NNCosNgbr-IB-ml-1M  run-NNCosNgbr-IB-ml-1M
# 16           run-SVD-ml-1M           run-SVD-ml-1M           run-SVD-ml-1M
# 17  run-NNCosNgbr-UB-ml-1M  run-NNCosNgbr-UB-ml-1M  run-NNCosNgbr-UB-ml-1M
# 18        run-Random-ml-1M        run-Random-ml-1M           run-UIR-ml-1M
# 19           run-UIR-ml-1M           run-UIR-ml-1M           run-Pop-ml-1M
# 20           run-Pop-ml-1M           run-Pop-ml-1M        run-Random-ml-1M
#
#                       0.98                    0.99                    1.00
# 0          run-BPRMF-ml-1M         run-BPRMF-ml-1M          run-SLIM-ml-1M
# 1           run-WRMF-ml-1M          run-WRMF-ml-1M         run-BPRMF-ml-1M
# 2           run-CHI2-ml-1M          run-SLIM-ml-1M          run-WRMF-ml-1M
# 3           run-SLIM-ml-1M          run-CHI2-ml-1M     run-LM-WSR-UB-ml-1M
# 4        run-PureSVD-ml-1M       run-PureSVD-ml-1M       run-PureSVD-ml-1M
# 5            run-LDA-ml-1M           run-LDA-ml-1M           run-RM2-ml-1M
# 6           run-PLSA-ml-1M          run-PLSA-ml-1M     run-LM-WSR-IB-ml-1M
# 7      run-LM-WSR-IB-ml-1M     run-LM-WSR-IB-ml-1M           run-LDA-ml-1M
# 8      run-LM-WSR-UB-ml-1M     run-LM-WSR-UB-ml-1M           run-KLD-ml-1M
# 9            run-RM2-ml-1M           run-RM2-ml-1M          run-PLSA-ml-1M
# 10           run-KLD-ml-1M           run-KLD-ml-1M            run-RW-ml-1M
# 11           run-RSV-ml-1M            run-RW-ml-1M           run-RSV-ml-1M
# 12            run-RW-ml-1M           run-RSV-ml-1M          run-CHI2-ml-1M
# 13           run-RM1-ml-1M           run-RM1-ml-1M           run-UIR-ml-1M
# 14            run-HT-ml-1M           run-UIR-ml-1M           run-Pop-ml-1M
# 15  run-NNCosNgbr-IB-ml-1M           run-Pop-ml-1M           run-RM1-ml-1M
# 16           run-UIR-ml-1M            run-HT-ml-1M  run-NNCosNgbr-UB-ml-1M
# 17           run-Pop-ml-1M  run-NNCosNgbr-IB-ml-1M           run-SVD-ml-1M
# 18  run-NNCosNgbr-UB-ml-1M  run-NNCosNgbr-UB-ml-1M            run-HT-ml-1M
# 19           run-SVD-ml-1M           run-SVD-ml-1M  run-NNCosNgbr-IB-ml-1M
# 20        run-Random-ml-1M        run-Random-ml-1M        run-Random-ml-1M
#
# [21 rows x 36 columns]
